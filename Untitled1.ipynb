# %%
! jupyter labextension install \
    @jupyter-widgets/jupyterlab-manager \
    jupyterlab_bokeh \
    qgrid \
    nbdime-jupyterlab;
# Out:
# /opt/conda/lib/python3.6/site-packages/notebook/services/kernels/kernelmanager.py:19: VisibleDeprecationWarning: zmq.eventloop.minitornado is deprecated in pyzmq 14.0 and will be removed.
#     Install tornado itself to use zmq with the tornado IOLoop.
#
#   from jupyter_client.session import Session
# Building jupyterlab assets (build:prod:minimize)

# %%
from bokeh.io import show, output_notebook
output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="ba67a452-fec5-4e46-a9f7-a6bb2a700716">Loading BokehJS ...</span>
#     </div>

# %%
from bokeh.sampledata.autompg import autompg_clean as df

df.cyl = df.cyl.astype(str)
df.yr = df.yr.astype(str)

# %%
! conda install -y -c plotly plotly=4.1.0
# Out:
# Solving environment: done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.5.8
#   latest version: 4.7.11
#
# Please update conda by running
#
#     $ conda update -n base conda
#
#
#
# ## Package Plan ##
#
#   environment location: /opt/conda
#
#   added / updated specs:
#     - plotly=4.1.0
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     retrying-1.3.3             |             py_2          11 KB  conda-forge
#     plotly-4.1.0               |             py_0         4.0 MB  plotly
#     ------------------------------------------------------------
#                                            Total:         4.0 MB
#
# The following NEW packages will be INSTALLED:
#
#     krb5:         1.16.1-h173b8e3_7       defaults
#     plotly:       4.1.0-py_0              plotly
#     retrying:     1.3.3-py_2              conda-forge
#
# The following packages will be UPDATED:
#
#     cryptography: 2.5-py36hb7f436b_1      conda-forge --> 2.7-py36h72c5cf5_0         conda-forge
#     libcurl:      7.61.0-h1ad7b7a_0       defaults    --> 7.65.3-h20c2e04_0          defaults
#     libedit:      3.1.20170329-0          conda-forge --> 3.1.20170329-hf8c457e_1001 conda-forge
#     libssh2:      1.8.0-h5b517e9_2        conda-forge --> 1.8.2-h22169c7_2           conda-forge
#     libstdcxx-ng: 7.2.0-hdf63c60_3        defaults    --> 9.1.0-hdf63c60_0           defaults
#     ncurses:      5.9-10                  conda-forge --> 6.1-hf484d3e_1002          conda-forge
#     openssl:      1.0.2r-h14c3975_0       conda-forge --> 1.1.1c-h516909a_0          conda-forge
#     pycurl:       7.43.0.2-py36hb7f436b_0 defaults    --> 7.43.0.2-py36h16ce93b_1    conda-forge
#     python:       3.6.5-1                 conda-forge --> 3.6.8-h0371630_0           defaults
#     readline:     7.0-0                   conda-forge --> 7.0-hf8c457e_1001          conda-forge
#     sqlite:       3.20.1-2                conda-forge --> 3.28.0-h8b20d00_0          conda-forge
#     xz:           5.2.3-0                 conda-forge --> 5.2.4-h14c3975_1001        conda-forge
#
#
# Downloading and Extracting Packages
# retrying-1.3.3       |   11 KB | ####################################### | 100%
# plotly-4.1.0         |  4.0 MB | ####################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done

# %%
import plotly.io as pio
pio.renderers.items
# Out:
# <bound method RenderersConfig.items of Renderers configuration
# -----------------------
#     Default renderer: 'iframe_connected'
#     Available renderers:
#         ['plotly_mimetype', 'jupyterlab', 'nteract', 'vscode',
#          'notebook', 'notebook_connected', 'kaggle', 'azure', 'colab',
#          'cocalc', 'databricks', 'json', 'png', 'jpeg', 'jpg', 'svg',
#          'pdf', 'browser', 'firefox', 'chrome', 'chromium', 'iframe',
#          'iframe_connected', 'sphinx_gallery']
# >

# %%
pio.renderers.default = 'iframe'

# %%
import plotly.graph_objects as go
fig = go.Figure(
    data=[go.Bar(y=[2, 1, 3])],
    layout_title_text="A Figure Displayed with fig.show()"
)
fig.show()
# Out:
# <iframe
#     scrolling="no"
#     width="100%"
#     height="545px"
#     src="iframe_figures/figure_30.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %%
! jupyter labextension install qgrid@1.1.0
# Out:
# /opt/conda/lib/python3.6/site-packages/notebook/services/kernels/kernelmanager.py:19: VisibleDeprecationWarning: zmq.eventloop.minitornado is deprecated in pyzmq 14.0 and will be removed.
#     Install tornado itself to use zmq with the tornado IOLoop.
#
#   from jupyter_client.session import Session
# Building jupyterlab assets (build:prod:minimize)

# %%
import qgrid._version as v; 
print(v.__version__)
# Out:
# 1.1.1

# %%
qgrid.enable()

# %%
df.data.grid()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-6-bd5f2ef6f4d4> in <module>
# ----> 1 df.data.grid()
#
# /opt/conda/lib/python3.6/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    4374             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    4375                 return self[name]
# -> 4376             return object.__getattribute__(self, name)
#    4377
#    4378     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'data'

# %%
import datalabframework as dlf

# %%
dlf.engine('spark')
# Out:
# created SparkEngine
# Init engine "spark"
# Connecting to spark master: local[*]
# Engine context spark:2.4.4 successfully started

# %%
df = dlf.load('data/raw/olist_customers_dataset.csv')

# %%
df.data.grid(render='jsgrid')
# Out:
# <link type="text/css" rel="stylesheet" href="https://cdnjs.cloudflare.com/ajax/libs/jsgrid/1.5.3/jsgrid.min.css" />
# <link type="text/css" rel="stylesheet" href="https://cdnjs.cloudflare.com/ajax/libs/jsgrid/1.5.3/jsgrid-theme.min.css" />
# <script type="text/javascript" src="https://cdnjs.cloudflare.com/ajax/libs/jsgrid/1.5.3/jsgrid.min.js"></script>
#
# <div id="jsGrid"></div>
#
# <script>
#     var clients = [
#         { "Name": "Otto Clay", "Age": 25, "Country": 1, "Address": "Ap #897-1459 Quam Avenue", "Married": false },
#         { "Name": "Connor Johnston", "Age": 45, "Country": 2, "Address": "Ap #370-4647 Dis Av.", "Married": true },
#         { "Name": "Lacey Hess", "Age": 29, "Country": 3, "Address": "Ap #365-8835 Integer St.", "Married": false },
#         { "Name": "Timothy Henson", "Age": 56, "Country": 1, "Address": "911-5143 Luctus Ave", "Married": true },
#         { "Name": "Ramona Benton", "Age": 32, "Country": 3, "Address": "Ap #614-689 Vehicula Street", "Married": false }
#     ];
#
#     db = []
#     var i;
#     for (i = 0; i < 10; i++) {
#         db = db.concat(clients)
#     }
#
#     var countries = [
#         { Name: "", Id: 0 },
#         { Name: "United States", Id: 1 },
#         { Name: "Canada", Id: 2 },
#         { Name: "United Kingdom", Id: 3 }
#     ];
#
#     $("#jsGrid").jsGrid({
#         width: "100%",
#         height: "400px",
#
#         heading: true,
#         filtering: true,
#         inserting: false,
#         editing: false,
#         selecting: false,
#         sorting: true,
#         paging: true,
#         pageLoading: false,
#         autoload: true,
#
#         pageSize: 15,
#         pageButtonCount: 3,
#
#         controller: {
#             loadData: function(filter) {
#                 //to do: filtering
#                 return db;
#             }
#         },
#
#         fields: [
#             { name: "Name", type: "text", width: 150, validate: "required" },
#             { name: "Age", type: "number", width: 50 },
#             { name: "Address", type: "text", width: 200 },
#             { name: "Country", type: "select", items: countries, valueField: "Id", textField: "Name" },
#             { name: "Married", type: "checkbox", title: "Is Married", sorting: false }
#         ]
#     });
# </script>

# %%
from IPython.core.display import display, HTML

html = """
<script type="text/javascript">
    var data = [
        { "Name": "Otto Clay", "Age": 25, "Country": 1, "Address": "Ap #897-1459 Quam Avenue", "Married": false },
        { "Name": "Connor Johnston", "Age": 45, "Country": 2, "Address": "Ap #370-4647 Dis Av.", "Married": true },
        { "Name": "Lacey Hess", "Age": 29, "Country": 3, "Address": "Ap #365-8835 Integer St.", "Married": false },
        { "Name": "Timothy Henson", "Age": 56, "Country": 1, "Address": "911-5143 Luctus Ave", "Married": true },
        { "Name": "Ramona Benton", "Age": 32, "Country": 3, "Address": "Ap #614-689 Vehicula Street", "Married": false },
        { "Name": "Otto Clay", "Age": 25, "Country": 1, "Address": "Ap #897-1459 Quam Avenue", "Married": false },
        { "Name": "Connor Johnston", "Age": 45, "Country": 2, "Address": "Ap #370-4647 Dis Av.", "Married": true },
        { "Name": "Lacey Hess", "Age": 29, "Country": 3, "Address": "Ap #365-8835 Integer St.", "Married": false },
        { "Name": "Timothy Henson", "Age": 56, "Country": 1, "Address": "911-5143 Luctus Ave", "Married": true },
        { "Name": "Ramona Benton", "Age": 32, "Country": 3, "Address": "Ap #614-689 Vehicula Street", "Married": false },
        { "Name": "Otto Clay", "Age": 25, "Country": 1, "Address": "Ap #897-1459 Quam Avenue", "Married": false },
        { "Name": "Connor Johnston", "Age": 45, "Country": 2, "Address": "Ap #370-4647 Dis Av.", "Married": true },
        { "Name": "Lacey Hess", "Age": 29, "Country": 3, "Address": "Ap #365-8835 Integer St.", "Married": false },
        { "Name": "Timothy Henson", "Age": 56, "Country": 1, "Address": "911-5143 Luctus Ave", "Married": true },
        { "Name": "Ramona Benton", "Age": 32, "Country": 3, "Address": "Ap #614-689 Vehicula Street", "Married": false },
        { "Name": "Otto Clay", "Age": 25, "Country": 1, "Address": "Ap #897-1459 Quam Avenue", "Married": false },
        { "Name": "Connor Johnston", "Age": 45, "Country": 2, "Address": "Ap #370-4647 Dis Av.", "Married": true },
        { "Name": "Lacey Hess", "Age": 29, "Country": 3, "Address": "Ap #365-8835 Integer St.", "Married": false },
        { "Name": "Timothy Henson", "Age": 56, "Country": 1, "Address": "911-5143 Luctus Ave", "Married": true },
        { "Name": "Ramona Benton", "Age": 32, "Country": 3, "Address": "Ap #614-689 Vehicula Street", "Married": false },
        { "Name": "Otto Clay", "Age": 25, "Country": 1, "Address": "Ap #897-1459 Quam Avenue", "Married": false },
        { "Name": "Connor Johnston", "Age": 45, "Country": 2, "Address": "Ap #370-4647 Dis Av.", "Married": true },
        { "Name": "Lacey Hess", "Age": 29, "Country": 3, "Address": "Ap #365-8835 Integer St.", "Married": false },
        { "Name": "Timothy Henson", "Age": 56, "Country": 1, "Address": "911-5143 Luctus Ave", "Married": true },
        { "Name": "Ramona Benton", "Age": 32, "Country": 3, "Address": "Ap #614-689 Vehicula Street", "Married": false },
        { "Name": "Otto Clay", "Age": 25, "Country": 1, "Address": "Ap #897-1459 Quam Avenue", "Married": false },
        { "Name": "Connor Johnston", "Age": 45, "Country": 2, "Address": "Ap #370-4647 Dis Av.", "Married": true },
        { "Name": "Lacey Hess", "Age": 29, "Country": 3, "Address": "Ap #365-8835 Integer St.", "Married": false },
        { "Name": "Timothy Henson", "Age": 56, "Country": 1, "Address": "911-5143 Luctus Ave", "Married": true },
        { "Name": "Ramona Benton", "Age": 32, "Country": 3, "Address": "Ap #614-689 Vehicula Street", "Married": false },
        { "Name": "Otto Clay", "Age": 25, "Country": 1, "Address": "Ap #897-1459 Quam Avenue", "Married": false },
        { "Name": "Connor Johnston", "Age": 45, "Country": 2, "Address": "Ap #370-4647 Dis Av.", "Married": true },
        { "Name": "Lacey Hess", "Age": 29, "Country": 3, "Address": "Ap #365-8835 Integer St.", "Married": false },
        { "Name": "Timothy Henson", "Age": 56, "Country": 1, "Address": "911-5143 Luctus Ave", "Married": true },
        { "Name": "Ramona Benton", "Age": 32, "Country": 3, "Address": "Ap #614-689 Vehicula Street", "Married": false },
        { "Name": "Otto Clay", "Age": 25, "Country": 1, "Address": "Ap #897-1459 Quam Avenue", "Married": false },
        { "Name": "Connor Johnston", "Age": 45, "Country": 2, "Address": "Ap #370-4647 Dis Av.", "Married": true },
        { "Name": "Lacey Hess", "Age": 29, "Country": 3, "Address": "Ap #365-8835 Integer St.", "Married": false },
        { "Name": "Timothy Henson", "Age": 56, "Country": 1, "Address": "911-5143 Luctus Ave", "Married": true },
        { "Name": "Ramona Benton", "Age": 32, "Country": 3, "Address": "Ap #614-689 Vehicula Street", "Married": false },
        { "Name": "Otto Clay", "Age": 25, "Country": 1, "Address": "Ap #897-1459 Quam Avenue", "Married": false },
        { "Name": "Connor Johnston", "Age": 45, "Country": 2, "Address": "Ap #370-4647 Dis Av.", "Married": true },
        { "Name": "Lacey Hess", "Age": 29, "Country": 3, "Address": "Ap #365-8835 Integer St.", "Married": false },
        { "Name": "Timothy Henson", "Age": 56, "Country": 1, "Address": "911-5143 Luctus Ave", "Married": true },
        { "Name": "Ramona Benton", "Age": 32, "Country": 3, "Address": "Ap #614-689 Vehicula Street", "Married": false },
        { "Name": "Otto Clay", "Age": 25, "Country": 1, "Address": "Ap #897-1459 Quam Avenue", "Married": false },
        { "Name": "Connor Johnston", "Age": 45, "Country": 2, "Address": "Ap #370-4647 Dis Av.", "Married": true },
        { "Name": "Lacey Hess", "Age": 29, "Country": 3, "Address": "Ap #365-8835 Integer St.", "Married": false },
        { "Name": "Timothy Henson", "Age": 56, "Country": 1, "Address": "911-5143 Luctus Ave", "Married": true },
        { "Name": "Ramona Benton", "Age": 32, "Country": 3, "Address": "Ap #614-689 Vehicula Street", "Married": false },
    ];
 
</script>
"""
html  += """
<link type="text/css" rel="stylesheet" href="https://cdnjs.cloudflare.com/ajax/libs/jsgrid/1.5.3/jsgrid.min.css" />
<link type="text/css" rel="stylesheet" href="https://cdnjs.cloudflare.com/ajax/libs/jsgrid/1.5.3/jsgrid-theme.min.css" />
<script type="text/javascript" src="https://cdnjs.cloudflare.com/ajax/libs/jsgrid/1.5.3/jsgrid.min.js"></script>

<div id="jsGrid"></div>

<script type="text/javascript">
$(function() {
 
    $("#jsGrid").jsGrid({
        height: "400px",
        width: "100%",
 
        filtering: true,
        editing: false,
        sorting: true,
        paging: true,
        autoload: true,
 
        pageSize: 15,
        pageButtonCount: 3,

        data: data,
 
        fields: [
            { name: "Name", type: "text" },
            { name: "Age", type: "number"},
            { name: "Address", type: "text"},
            { name: "Country", type: "text"},
            { name: "Married", type: "checkbox"}
        ]
    });
 
});
</script>
"""
display(HTML(html))
# Out:
# <script type="text/javascript">
#     var data = [
#         { "Name": "Otto Clay", "Age": 25, "Country": 1, "Address": "Ap #897-1459 Quam Avenue", "Married": false },
#         { "Name": "Connor Johnston", "Age": 45, "Country": 2, "Address": "Ap #370-4647 Dis Av.", "Married": true },
#         { "Name": "Lacey Hess", "Age": 29, "Country": 3, "Address": "Ap #365-8835 Integer St.", "Married": false },
#         { "Name": "Timothy Henson", "Age": 56, "Country": 1, "Address": "911-5143 Luctus Ave", "Married": true },
#         { "Name": "Ramona Benton", "Age": 32, "Country": 3, "Address": "Ap #614-689 Vehicula Street", "Married": false },
#         { "Name": "Otto Clay", "Age": 25, "Country": 1, "Address": "Ap #897-1459 Quam Avenue", "Married": false },
#         { "Name": "Connor Johnston", "Age": 45, "Country": 2, "Address": "Ap #370-4647 Dis Av.", "Married": true },
#         { "Name": "Lacey Hess", "Age": 29, "Country": 3, "Address": "Ap #365-8835 Integer St.", "Married": false },
#         { "Name": "Timothy Henson", "Age": 56, "Country": 1, "Address": "911-5143 Luctus Ave", "Married": true },
#         { "Name": "Ramona Benton", "Age": 32, "Country": 3, "Address": "Ap #614-689 Vehicula Street", "Married": false },
#         { "Name": "Otto Clay", "Age": 25, "Country": 1, "Address": "Ap #897-1459 Quam Avenue", "Married": false },
#         { "Name": "Connor Johnston", "Age": 45, "Country": 2, "Address": "Ap #370-4647 Dis Av.", "Married": true },
#         { "Name": "Lacey Hess", "Age": 29, "Country": 3, "Address": "Ap #365-8835 Integer St.", "Married": false },
#         { "Name": "Timothy Henson", "Age": 56, "Country": 1, "Address": "911-5143 Luctus Ave", "Married": true },
#         { "Name": "Ramona Benton", "Age": 32, "Country": 3, "Address": "Ap #614-689 Vehicula Street", "Married": false },
#         { "Name": "Otto Clay", "Age": 25, "Country": 1, "Address": "Ap #897-1459 Quam Avenue", "Married": false },
#         { "Name": "Connor Johnston", "Age": 45, "Country": 2, "Address": "Ap #370-4647 Dis Av.", "Married": true },
#         { "Name": "Lacey Hess", "Age": 29, "Country": 3, "Address": "Ap #365-8835 Integer St.", "Married": false },
#         { "Name": "Timothy Henson", "Age": 56, "Country": 1, "Address": "911-5143 Luctus Ave", "Married": true },
#         { "Name": "Ramona Benton", "Age": 32, "Country": 3, "Address": "Ap #614-689 Vehicula Street", "Married": false },
#         { "Name": "Otto Clay", "Age": 25, "Country": 1, "Address": "Ap #897-1459 Quam Avenue", "Married": false },
#         { "Name": "Connor Johnston", "Age": 45, "Country": 2, "Address": "Ap #370-4647 Dis Av.", "Married": true },
#         { "Name": "Lacey Hess", "Age": 29, "Country": 3, "Address": "Ap #365-8835 Integer St.", "Married": false },
#         { "Name": "Timothy Henson", "Age": 56, "Country": 1, "Address": "911-5143 Luctus Ave", "Married": true },
#         { "Name": "Ramona Benton", "Age": 32, "Country": 3, "Address": "Ap #614-689 Vehicula Street", "Married": false },
#         { "Name": "Otto Clay", "Age": 25, "Country": 1, "Address": "Ap #897-1459 Quam Avenue", "Married": false },
#         { "Name": "Connor Johnston", "Age": 45, "Country": 2, "Address": "Ap #370-4647 Dis Av.", "Married": true },
#         { "Name": "Lacey Hess", "Age": 29, "Country": 3, "Address": "Ap #365-8835 Integer St.", "Married": false },
#         { "Name": "Timothy Henson", "Age": 56, "Country": 1, "Address": "911-5143 Luctus Ave", "Married": true },
#         { "Name": "Ramona Benton", "Age": 32, "Country": 3, "Address": "Ap #614-689 Vehicula Street", "Married": false },
#         { "Name": "Otto Clay", "Age": 25, "Country": 1, "Address": "Ap #897-1459 Quam Avenue", "Married": false },
#         { "Name": "Connor Johnston", "Age": 45, "Country": 2, "Address": "Ap #370-4647 Dis Av.", "Married": true },
#         { "Name": "Lacey Hess", "Age": 29, "Country": 3, "Address": "Ap #365-8835 Integer St.", "Married": false },
#         { "Name": "Timothy Henson", "Age": 56, "Country": 1, "Address": "911-5143 Luctus Ave", "Married": true },
#         { "Name": "Ramona Benton", "Age": 32, "Country": 3, "Address": "Ap #614-689 Vehicula Street", "Married": false },
#         { "Name": "Otto Clay", "Age": 25, "Country": 1, "Address": "Ap #897-1459 Quam Avenue", "Married": false },
#         { "Name": "Connor Johnston", "Age": 45, "Country": 2, "Address": "Ap #370-4647 Dis Av.", "Married": true },
#         { "Name": "Lacey Hess", "Age": 29, "Country": 3, "Address": "Ap #365-8835 Integer St.", "Married": false },
#         { "Name": "Timothy Henson", "Age": 56, "Country": 1, "Address": "911-5143 Luctus Ave", "Married": true },
#         { "Name": "Ramona Benton", "Age": 32, "Country": 3, "Address": "Ap #614-689 Vehicula Street", "Married": false },
#         { "Name": "Otto Clay", "Age": 25, "Country": 1, "Address": "Ap #897-1459 Quam Avenue", "Married": false },
#         { "Name": "Connor Johnston", "Age": 45, "Country": 2, "Address": "Ap #370-4647 Dis Av.", "Married": true },
#         { "Name": "Lacey Hess", "Age": 29, "Country": 3, "Address": "Ap #365-8835 Integer St.", "Married": false },
#         { "Name": "Timothy Henson", "Age": 56, "Country": 1, "Address": "911-5143 Luctus Ave", "Married": true },
#         { "Name": "Ramona Benton", "Age": 32, "Country": 3, "Address": "Ap #614-689 Vehicula Street", "Married": false },
#         { "Name": "Otto Clay", "Age": 25, "Country": 1, "Address": "Ap #897-1459 Quam Avenue", "Married": false },
#         { "Name": "Connor Johnston", "Age": 45, "Country": 2, "Address": "Ap #370-4647 Dis Av.", "Married": true },
#         { "Name": "Lacey Hess", "Age": 29, "Country": 3, "Address": "Ap #365-8835 Integer St.", "Married": false },
#         { "Name": "Timothy Henson", "Age": 56, "Country": 1, "Address": "911-5143 Luctus Ave", "Married": true },
#         { "Name": "Ramona Benton", "Age": 32, "Country": 3, "Address": "Ap #614-689 Vehicula Street", "Married": false },
#     ];
#
# </script>
#
# <link type="text/css" rel="stylesheet" href="https://cdnjs.cloudflare.com/ajax/libs/jsgrid/1.5.3/jsgrid.min.css" />
# <link type="text/css" rel="stylesheet" href="https://cdnjs.cloudflare.com/ajax/libs/jsgrid/1.5.3/jsgrid-theme.min.css" />
# <script type="text/javascript" src="https://cdnjs.cloudflare.com/ajax/libs/jsgrid/1.5.3/jsgrid.min.js"></script>
#
# <div id="jsGrid"></div>
#
# <script type="text/javascript">
# $(function() {
#
#     $("#jsGrid").jsGrid({
#         height: "400px",
#         width: "100%",
#
#         filtering: true,
#         editing: false,
#         sorting: true,
#         paging: true,
#         autoload: true,
#
#         pageSize: 15,
#         pageButtonCount: 3,
#
#         data: data,
#
#         fields: [
#             { name: "Name", type: "text" },
#             { name: "Age", type: "number"},
#             { name: "Address", type: "text"},
#             { name: "Country", type: "text"},
#             { name: "Married", type: "checkbox"}
#         ]
#     });
#
# });
# </script>

# %%
from IPython.core.display import display, HTML

html = """
<link type="text/css" rel="stylesheet" href="https://cdnjs.cloudflare.com/ajax/libs/jsgrid/1.5.3/jsgrid.min.css" />
<link type="text/css" rel="stylesheet" href="https://cdnjs.cloudflare.com/ajax/libs/jsgrid/1.5.3/jsgrid-theme.min.css" />
<script type="text/javascript" src="https://cdnjs.cloudflare.com/ajax/libs/jsgrid/1.5.3/jsgrid.min.js"></script>

<div id="jsGrid"></div>

<script>
    var clients = [
        { "Name": "Otto Clay", "Age": 25, "Country": 1, "Address": "Ap #897-1459 Quam Avenue", "Married": false },
        { "Name": "Connor Johnston", "Age": 45, "Country": 2, "Address": "Ap #370-4647 Dis Av.", "Married": true },
        { "Name": "Lacey Hess", "Age": 29, "Country": 3, "Address": "Ap #365-8835 Integer St.", "Married": false },
        { "Name": "Timothy Henson", "Age": 56, "Country": 1, "Address": "911-5143 Luctus Ave", "Married": true },
        { "Name": "Ramona Benton", "Age": 32, "Country": 3, "Address": "Ap #614-689 Vehicula Street", "Married": false }
    ];
 
    var countries = [
        { Name: "", Id: 0 },
        { Name: "United States", Id: 1 },
        { Name: "Canada", Id: 2 },
        { Name: "United Kingdom", Id: 3 }
    ];
 
    $("#jsGrid").jsGrid({
        width: "100%",
        height: "400px",
 
        heading: true,
        filtering: true,
        inserting: false,
        editing: false,
        selecting: false,
        sorting: true,
        paging: true,
        pageLoading: false,
        autoload: true,

        pageSize: 15,
        pageButtonCount: 3,
        
        controller: {
            loadData: function(filter) {
                //to do: filtering
                return clients;
            }
        },

        fields: [
            { name: "Name", type: "text", width: 150, validate: "required" },
            { name: "Age", type: "number", width: 50 },
            { name: "Address", type: "text", width: 200 },
            { name: "Country", type: "select", items: countries, valueField: "Id", textField: "Name" },
            { name: "Married", type: "checkbox", title: "Is Married", sorting: false }
        ]
    });
</script>
"""
display(HTML(html))
# Out:
# <link type="text/css" rel="stylesheet" href="https://cdnjs.cloudflare.com/ajax/libs/jsgrid/1.5.3/jsgrid.min.css" />
# <link type="text/css" rel="stylesheet" href="https://cdnjs.cloudflare.com/ajax/libs/jsgrid/1.5.3/jsgrid-theme.min.css" />
# <script type="text/javascript" src="https://cdnjs.cloudflare.com/ajax/libs/jsgrid/1.5.3/jsgrid.min.js"></script>
#
# <div id="jsGrid1"></div>
#
# <script>
#     var clients = [
#         { "Name": "Otto Clay", "Age": 25, "Country": 1, "Address": "Ap #897-1459 Quam Avenue", "Married": false },
#         { "Name": "Connor Johnston", "Age": 45, "Country": 2, "Address": "Ap #370-4647 Dis Av.", "Married": true },
#         { "Name": "Lacey Hess", "Age": 29, "Country": 3, "Address": "Ap #365-8835 Integer St.", "Married": false },
#         { "Name": "Timothy Henson", "Age": 56, "Country": 1, "Address": "911-5143 Luctus Ave", "Married": true },
#         { "Name": "Ramona Benton", "Age": 32, "Country": 3, "Address": "Ap #614-689 Vehicula Street", "Married": false }
#     ];
#
#     var countries = [
#         { Name: "", Id: 0 },
#         { Name: "United States", Id: 1 },
#         { Name: "Canada", Id: 2 },
#         { Name: "United Kingdom", Id: 3 }
#     ];
#
#     $("#jsGrid1").jsGrid({
#         width: "100%",
#         height: "400px",
#
#         heading: true,
#         filtering: true,
#         inserting: false,
#         editing: false,
#         selecting: false,
#         sorting: true,
#         paging: true,
#         pageLoading: false,
#         autoload: true,
#
#         pageSize: 15,
#         pageButtonCount: 3,
#
#         controller: {
#             loadData: function(filter) {
#                 //to do: filtering
#                 return clients;
#             }
#         },
#
#         fields: [
#             { name: "Name", type: "text", width: 150, validate: "required" },
#             { name: "Age", type: "number", width: 50 },
#             { name: "Address", type: "text", width: 200 },
#             { name: "Country", type: "select", items: countries, valueField: "Id", textField: "Name" },
#             { name: "Married", type: "checkbox", title: "Is Married", sorting: false }
#         ]
#     });
# </script>

# %%
df.data.grid()
# Out:
#                           customer_id                customer_unique_id  \
# 0    06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1    18955e83d337fd6b2def6b18a428ac77  290c77bc529b7ac935b93aa66c333dc3
# 2    4e7b3e00288586ebd08712fdd0374a03  060e732b5b29e8181a18229c7b0b2b5e
# 3    b2b6027bc5c5109e529d4dc6358b12c3  259dac757896d24d7702b9acbbff3f3c
# 4    4f2d8ab171c80ec8364f7c12e35b23ad  345ecd01c38d18a9036ed96c73b8d066
# 5    879864dab9bc3047522c92c82e1212b8  4c93744516667ad3b8f1fb645a3116a4
# 6    fd826e7cf63160e536e0908c76c3f441  addec96d2e059c80c30fe6871d30d177
# 7    5e274e7a0c3809e14aba7ad5aae0d407  57b2a98a409812fe9618067b6b8ebe4f
# 8    5adf08e34b2e993982a47070956c5c65  1175e95fb47ddff9de6b2b06188f7e0d
# 9    4b7139f34592b3a31687243a302fa75b  9afe194fb833f79e300e37e580171f22
# 10   9fb35e4ed6f0a14a4977cd9aea4042bb  2a7745e1ed516b289ed9b29c7d0539a5
# 11   5aa9e4fdd4dfd20959cad2d772509598  2a46fb94aef5cbeeb850418118cee090
# 12   b2d1536598b73a9abd18e0d75d92f0a3  918dc87cd72cd9f6ed4bd442ed785235
# 13   eabebad39a88bb6f5b52376faec28612  295c05e81917928d76245e842748184d
# 14   1f1c7bf1c9b041b292af6c1c4470b753  3151a81801c8386361b62277d7fa5ecf
# 15   206f3129c0e4d7d0b9550426023f0a08  21f748a16f4e1688a9014eb3ee6fa325
# 16   a7c125a0a07b75146167b7f04a7f8e98  5c2991dbd08bbf3cf410713c4de5a0b5
# 17   c5c61596a3b6bd0cee5766992c48a9a1  b6e99561fe6f34a55b0b7da92f8ed775
# 18   9b8ce803689b3562defaad4613ef426f  7f3a72e8f988c6e735ba118d54f47458
# 19   49d0ea0986edde72da777f15456a0ee0  3e6fd6b2f0d499456a6a6820a40f2d79
# 20   154c4ded6991bdfa3cd249d11abf4130  e607ede0e63436308660236f5a52da5e
# 21   690172ab319622688d3b4df42f676898  a96d5cfa0d3181817e2b946f921ea021
# 22   2938121a40a20953c43caa8c98787fcb  482441ea6a06b1f72fe9784756c0ea75
# 23   237098a64674ae89babdc426746260fc  4390ddbb6276a66ff1736a6710205dca
# 24   cb721d7b4f271fd87011c4c83462c076  a5844ba4bfc8d0cc61d13027c7e63bcc
# 25   f681356046d9fde60e70c73a18d65ea2  5f102dd37243f152aec3607970aad100
# 26   167bd30a409e3e4127df5a9408ebd394  9c0096673baf55453a50073f12d1a37f
# 27   6e359a57a91f84095cc64e1b351aef8c  2e6a42a9b5cbb0da62988694f18ee295
# 28   e0eea8f69a457b3f1fa246e44c9ebefd  4d221875624017bc47b4d1ce7314a5b7
# 29   e3109970a3fe8021d5ff82c577ce5606  a8654e2af5da6bb72f52c22b164855e1
# ..                                ...                               ...
# 970  dee7ac1315330a02d049ad3b108c7ad4  16d778764561c820ab02b6ea12796b14
# 971  5d31ddffc029174e9dac6e1fdb4f75a7  4232024117e4618d2cfdc07c30b5d3c7
# 972  bb38dcdbc99e5fbf1ca0dc4f8c6b2f4e  efdfdcb4890f42ff5fdc077b298f9af8
# 973  52aaa28398bf43dfbfc64dc09278f13d  28aea3e12549a3611bbd8d4e3310e4fa
# 974  856d87f37ded3711e685ea724e5ca248  b3285dd7fd409eaa193f78dbd67f70d2
# 975  7927dfaf0bee1bf23b4e9203355497c0  fbb97973142894c3265d06e676820c5a
# 976  66acec0b594d1e6da7e248d3172fcc43  39d7ce28dfadb187458ae98f1e7e3857
# 977  6cb393c4edd43586fc9eb664579e6622  38e31fda99a5fb901d27134d18d36c75
# 978  5bde57569eb8318a2306865d06de2bfb  6ce73016161f051b4267667a28bb417e
# 979  8610db3f7a37d8a445f5649be9343960  48464d1565a9447566fa926099aa5d9b
# 980  341c4634e0f68d32b278e42dc843b433  2a9c0f0e5f06e91c50c74baf4dc67a0f
# 981  93e0dbadcb03b5b82294f9a7dfd303e5  6b3e85b566abefbb24c346a5c2faf23f
# 982  af37bca8ff1fece07b46d92c0ed306af  f5e97c4a357a49248114891b8b69fd80
# 983  e5fe29371fab568cd043942ae42365ed  794dcff1cc7dee09bea35d1d20994c99
# 984  33cb0e2958def1ed82a542a45b13c982  c8fa956730a8b291e6bada90a5c6db6c
# 985  17cc67a8e493d2fc6c761f39b4ee9648  6e9c6c2120611104445c767b78377d21
# 986  a18e4956844fab232555e2bfd53eca5e  b4b26faae91bc1b8f9458d29bc3c200c
# 987  f85c1412c63126bbfaa30cac5590c0aa  9e80855aee7a17e3e214da66f7d1c08f
# 988  e4b6766132b13b3ab3edd2b7be4b915e  7a6156ef7451bb5f25556d7332d1cf77
# 989  07cc6026f1fba9869ce6efc681fd190d  12bc33b0d41518a36034c53c10e37129
# 990  c9507333f1adf471ae7b77aa0f137277  6fa75bcd8374aaf022bf590a4aad45e2
# 991  5d8f7d35350a0802b7e4bea9671b132a  589ee29a3decf9bd5cd8492da02efb2e
# 992  4b6484fa6c4406d63dca39c2f421d2b4  b087812101562e36a7b1c11c1540c3bd
# 993  851406b866022c60fdb8a6e862808933  43f0b8fa25a050c02dc18e166ed574ef
# 994  269e3d5f088fc1f4b2a81eb0ce8ce7d6  bb4a329975df85aa69684e124f0b48b1
# 995  84224aa8a8d7d7a16e6ed976990b9cdf  93805ba8be262fe253c4284751762866
# 996  7795ad64f8c82d9dc38060df2f3ceab2  db94b7a9542eb59e1d8d0e7191013354
# 997  3fcc0ad6fc4d2cb5b8ab39309e1ac335  4bac35931842898ef246fe185e61f7b3
# 998  58010882ac48cc7801627ad2bcd383e4  f1bb87ce3b511f772f77765bd3fcef6a
# 999  897b42a91c4c99a830882d3470ecbb5f  fbcafae33b8ac7b85dcbb5ff0cad932e
#
#      customer_zip_code_prefix            customer_city customer_state
# 0                       14409                   franca             SP
# 1                        9790    sao bernardo do campo             SP
# 2                        1151                sao paulo             SP
# 3                        8775          mogi das cruzes             SP
# 4                       13056                 campinas             SP
# 5                       89254           jaragua do sul             SC
# 6                        4534                sao paulo             SP
# 7                       35182                  timoteo             MG
# 8                       81560                 curitiba             PR
# 9                       30575           belo horizonte             MG
# 10                      39400            montes claros             MG
# 11                      20231           rio de janeiro             RJ
# 12                      18682         lencois paulista             SP
# 13                       5704                sao paulo             SP
# 14                      95110            caxias do sul             RS
# 15                      13412               piracicaba             SP
# 16                      22750           rio de janeiro             RJ
# 17                       7124                guarulhos             SP
# 18                       5416                sao paulo             SP
# 19                      68485                   pacaja             PA
# 20                      88034            florianopolis             SC
# 21                      74914     aparecida de goiania             GO
# 22                       5713                sao paulo             SP
# 23                      82820                 curitiba             PR
# 24                       8225                sao paulo             SP
# 25                       9121              santo andre             SP
# 26                      74310                  goiania             GO
# 27                       4571                sao paulo             SP
# 28                      29311  cachoeiro de itapemirim             ES
# 29                       5528                sao paulo             SP
# ..                        ...                      ...            ...
# 970                     38410               uberlandia             MG
# 971                     12721                 cruzeiro             SP
# 972                     60822                fortaleza             CE
# 973                     22070           rio de janeiro             RJ
# 974                     28495                  aperibe             RJ
# 975                     96810        santa cruz do sul             RS
# 976                      3420                sao paulo             SP
# 977                     30644           belo horizonte             MG
# 978                     90450             porto alegre             RS
# 979                     27213            volta redonda             RJ
# 980                     19470      presidente epitacio             SP
# 981                     90620             porto alegre             RS
# 982                     30610           belo horizonte             MG
# 983                     89228                joinville             SC
# 984                     29124               vila velha             ES
# 985                      9431           ribeirao pires             SP
# 986                     68745                castanhal             PA
# 987                     66085                    belem             PA
# 988                     12286                 cacapava             SP
# 989                     34000                nova lima             MG
# 990                      3319                sao paulo             SP
# 991                     29155                cariacica             ES
# 992                     32143                 contagem             MG
# 993                     85035               guarapuava             PR
# 994                      4040                sao paulo             SP
# 995                     12955    bom jesus dos perdoes             SP
# 996                     35160                 ipatinga             MG
# 997                     69180              urucurituba             AM
# 998                      6624                  jandira             SP
# 999                     53130                   olinda             PE
#
# [1000 rows x 5 columns]

# %%
! jupyter nbextension enable --py --sys-prefix qgrid
! jupyter nbextension enable --py --sys-prefix widgetsnbextension
# Out:
# /opt/conda/lib/python3.6/site-packages/ipykernel/kernelbase.py:19: VisibleDeprecationWarning: zmq.eventloop.minitornado is deprecated in pyzmq 14.0 and will be removed.
#     Install tornado itself to use zmq with the tornado IOLoop.
#
#   from jupyter_client.session import utcnow as now
# Enabling notebook extension qgrid/extension...
#       - Validating: OK
# Enabling notebook extension jupyter-js-widgets/extension...
#       - Validating: OK

# %%
from pyspark.sql import SparkSession

spark = ( SparkSession
          .builder
          .appName("Python Spark SQL basic example")
          .getOrCreate())

print(spark.version)
# Out:
# 2.4.4
